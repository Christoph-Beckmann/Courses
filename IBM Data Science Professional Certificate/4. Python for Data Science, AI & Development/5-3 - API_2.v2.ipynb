# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>
#
# # Simple APIs
#
# ## Random User and Fruitvice API Examples
#
# Estimated time needed: **25** minutes
#
# ## Objectives
#
# After completing this lab you will be able to:
#
# *   Load and use RandomUser API, using `RandomUser()` Python library
# *   Load and use Fruitvice API, using `requests` Python library

# %% [markdown]
# The purpose of this notebook is to provide more examples on how to use simple APIs. As you have already learned from previous videos and notebooks, API stands for Application Programming Interface and is a software intermediary that allows two applications to talk to each other.
#
# The advantages of using APIs:
#
# *   **Automation**. Less human effort is required and workflows can be easily updated to become faster and more\
#     productive.
# *   **Efficiency**. It allows to use the capabilities of one of the already developed APIs than to try to
#     independently implement some functionality from scratch.
#
# The disadvantage of using APIs:
#
# *   **Secirity**. If the API is poorly integrated, it means it will be vulnerable to attacks, resulting in data\
#     breeches or losses having financial or reputation implications.
#
# One of the applications we will use in this notebook is Random User Generator. RandomUser is an open-source, free API providing developers with randomly generated users to be used as placeholders for testing purposes. This makes the tool similar to Lorem Ipsum, but is a placeholder for people instead of text. The API can return multiple results, as well as specify generated user details such as gender, email, image, username, address, title, first and last name, and more. More information on [RandomUser](https://randomuser.me/documentation?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0101ENSkillsNetwork19487395-2022-01-01#intro) can be found here.
#
# Another example of simple API we will use in this notebook is Fruitvice application. The Fruitvice API webservice which provides data for all kinds of fruit! You can use Fruityvice to find out interesting information about fruit and educate yourself. The webservice is completely free to use and contribute to.

# %% [markdown]
# ## Example 1: RandomUser API
#
# Bellow are Get Methods parameters that we can generate. For more information on the parameters, please visit this [documentation](https://randomuser.me/documentation?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0101ENSkillsNetwork19487395-2022-01-01) page.

# %% [markdown]
# ## **Get Methods**
#
# *   get_cell()
# *   get_city()
# *   get_dob()
# *   get_email()
# *   get_first_name()
# *   get_full_name()
# *   get_gender()
# *   get_id()
# *   get_id_number()
# *   get_id_type()
# *   get_info()
# *   get_last_name()
# *   get_login_md5()
# *   get_login_salt()
# *   get_login_sha1()
# *   get_login_sha256()
# *   get_nat()
# *   get_password()
# *   get_phone()
# *   get_picture()
# *   get_postcode()
# *   get_registered()
# *   get_state()
# *   get_street()
# *   get_username()
# *   get_zipcode()

# %% [markdown]
# To start using the API you can install the `randomuser` library running the `pip install` command.

# %%
# !pip install randomuser
# !pip list
# Out:
# Requirement already satisfied: randomuser in /Users/christophbeckmann/opt/anaconda3/lib/python3.9/site-packages (1.6)
# Package                       Version
# ----------------------------- --------------------
# aiohttp                       3.8.1
# aiosignal                     1.2.0
# alabaster                     0.7.12
# anaconda-client               1.9.0
# anaconda-navigator            2.1.4
# anaconda-project              0.10.2
# anyio                         3.5.0
# appdirs                       1.4.4
# applaunchservices             0.2.1
# appnope                       0.1.2
# appscript                     1.1.2
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# arrow                         1.2.2
# astroid                       2.6.6
# astropy                       5.0.4
# asttokens                     2.0.5
# async-timeout                 4.0.2
# atomicwrites                  1.4.0
# attrs                         21.4.0
# Automat                       20.2.0
# autopep8                      1.6.0
# Babel                         2.9.1
# backcall                      0.2.0
# backports.functools-lru-cache 1.6.4
# backports.tempfile            1.0
# backports.weakref             1.0.post1
# bcrypt                        3.2.0
# beautifulsoup4                4.11.1
# binaryornot                   0.4.4
# bitarray                      2.4.1
# bkcharts                      0.2
# black                         19.10b0
# bleach                        4.1.0
# bokeh                         2.4.2
# boto3                         1.21.32
# botocore                      1.24.32
# Bottleneck                    1.3.4
# Brotli                        1.0.9
# brotlipy                      0.7.0
# cachetools                    4.2.2
# certifi                       2022.6.15
# cffi                          1.15.0
# chardet                       4.0.0
# charset-normalizer            2.0.4
# click                         8.0.4
# cloudpickle                   2.0.0
# clyent                        1.2.2
# colorama                      0.4.4
# colorcet                      2.0.6
# commonmark                    0.9.1
# conda                         4.14.0
# conda-build                   3.21.8
# conda-content-trust           0+unknown
# conda-pack                    0.6.0
# conda-package-handling        1.8.1
# conda-repo-cli                1.0.4
# conda-token                   0.3.0
# conda-verify                  3.4.2
# constantly                    15.1.0
# cookiecutter                  1.7.3
# cryptography                  3.4.8
# cssselect                     1.1.0
# cycler                        0.11.0
# Cython                        0.29.28
# cytoolz                       0.11.0
# daal4py                       2021.5.0
# dask                          2022.2.1
# datashader                    0.13.0
# datashape                     0.5.4
# DateTime                      4.5
# debugpy                       1.5.1
# decorator                     5.1.1
# deepl-cli                     0.2.3
# defusedxml                    0.7.1
# Deprecated                    1.2.13
# diff-match-patch              20200713
# distlib                       0.3.4
# distributed                   2022.2.1
# docutils                      0.17.1
# entrypoints                   0.4
# et-xmlfile                    1.1.0
# executing                     0.8.3
# fastjsonschema                2.15.1
# filelock                      3.6.0
# flake8                        3.9.2
# Flask                         1.1.2
# fonttools                     4.25.0
# frozenlist                    1.2.0
# fsspec                        2022.2.0
# future                        0.18.2
# gensim                        4.1.2
# glob2                         0.7
# gmpy2                         2.1.2
# google-api-core               1.25.1
# google-auth                   1.33.0
# google-cloud-core             1.7.1
# google-cloud-storage          1.31.0
# google-crc32c                 1.1.2
# google-resumable-media        1.3.1
# googleapis-common-protos      1.53.0
# graphviz                      0.20.1
# greenlet                      1.1.1
# grpcio                        1.42.0
# h5py                          3.6.0
# HeapDict                      1.0.1
# holoviews                     1.14.8
# hvplot                        0.7.3
# hyperlink                     21.0.0
# idna                          3.3
# imagecodecs                   2021.8.26
# imageio                       2.9.0
# imagesize                     1.3.0
# importlib-metadata            4.11.3
# incremental                   21.3.0
# inflection                    0.5.1
# iniconfig                     1.1.1
# intake                        0.6.5
# intervaltree                  3.1.0
# ipykernel                     6.9.1
# ipython                       8.2.0
# ipython-genutils              0.2.0
# ipywidgets                    7.6.5
# isort                         5.9.3
# itemadapter                   0.3.0
# itemloaders                   1.0.4
# itsdangerous                  2.0.1
# jarowinkler                   1.1.2
# jdcal                         1.4.1
# jedi                          0.18.1
# Jinja2                        2.11.3
# jinja2-time                   0.2.0
# jmespath                      0.10.0
# joblib                        1.1.0
# json5                         0.9.6
# jsonschema                    4.4.0
# jupyter                       1.0.0
# jupyter-client                6.1.12
# jupyter-console               6.4.0
# jupyter-core                  4.9.2
# jupyter-server                1.13.5
# jupyterlab                    3.3.2
# jupyterlab-pygments           0.1.2
# jupyterlab-server             2.10.3
# jupyterlab-widgets            1.0.0
# keyring                       23.4.0
# kiwisolver                    1.3.2
# langdetect                    1.0.9
# lazy-object-proxy             1.6.0
# libarchive-c                  2.9
# llvmlite                      0.38.0
# locket                        0.2.1
# lxml                          4.8.0
# Markdown                      3.3.4
# MarkupSafe                    2.0.1
# matplotlib                    3.5.1
# matplotlib-inline             0.1.2
# mccabe                        0.6.1
# mistune                       0.8.4
# mkl-fft                       1.3.1
# mkl-random                    1.2.2
# mkl-service                   2.4.0
# mock                          4.0.3
# mpmath                        1.2.1
# msgpack                       1.0.2
# multidict                     5.2.0
# multipledispatch              0.6.0
# munkres                       1.1.4
# mutagen                       1.45.1
# mypy-extensions               0.4.3
# navigator-updater             0.2.1
# nbclassic                     0.3.5
# nbclient                      0.5.13
# nbconvert                     6.4.4
# nbformat                      5.3.0
# nest-asyncio                  1.5.5
# networkx                      2.7.1
# nltk                          3.7
# nose                          1.3.7
# notebook                      6.4.8
# numba                         0.55.1
# numexpr                       2.8.1
# numpy                         1.22.2
# numpydoc                      1.2
# olefile                       0.46
# openpyxl                      3.0.9
# packaging                     21.3
# pandas                        1.4.2
# pandocfilters                 1.5.0
# panel                         0.13.0
# param                         1.12.0
# parsel                        1.6.0
# parso                         0.8.3
# partd                         1.2.0
# pathspec                      0.7.0
# patsy                         0.5.2
# pep8                          1.7.1
# pexpect                       4.8.0
# pickleshare                   0.7.5
# Pillow                        9.0.1
# pip                           21.2.4
# pkginfo                       1.8.2
# platformdirs                  2.5.2
# plotly                        5.6.0
# pluggy                        1.0.0
# poyo                          0.5.0
# prometheus-client             0.13.1
# prompt-toolkit                3.0.20
# Protego                       0.1.16
# protobuf                      3.19.1
# psutil                        5.8.0
# ptyprocess                    0.7.0
# pure-eval                     0.2.2
# py                            1.11.0
# pyasn1                        0.4.8
# pyasn1-modules                0.2.8
# pycodestyle                   2.7.0
# pycosat                       0.6.3
# pycparser                     2.21
# pycryptodomex                 3.15.0
# pyct                          0.4.6
# pycurl                        7.44.1
# PyDispatcher                  2.0.5
# pydocstyle                    6.1.1
# pyee                          8.2.2
# pyerfa                        2.0.0
# pyflakes                      2.3.1
# Pygments                      2.11.2
# PyHamcrest                    2.0.2
# PyJWT                         2.1.0
# pylint                        2.9.6
# pyls-spyder                   0.4.0
# pyodbc                        4.0.32
# pyOpenSSL                     21.0.0
# pyparsing                     3.0.4
# pyppeteer                     1.0.2
# pyrsistent                    0.18.0
# PySocks                       1.7.1
# pytest                        7.1.1
# python-dateutil               2.8.2
# python-lsp-black              1.0.0
# python-lsp-jsonrpc            1.0.0
# python-lsp-server             1.2.4
# python-slugify                5.0.2
# python-snappy                 0.6.0
# pytube                        12.1.0
# pytz                          2021.3
# pyviz-comms                   2.0.2
# PyWavelets                    1.3.0
# PyYAML                        6.0
# pyzmq                         22.3.0
# QDarkStyle                    3.0.2
# qstylizer                     0.1.10
# QtAwesome                     1.0.3
# qtconsole                     5.3.0
# QtPy                          2.0.1
# queuelib                      1.5.0
# randomuser                    1.6
# rapidfuzz                     2.1.3
# redis                         4.3.4
# regex                         2022.3.15
# requests                      2.27.1
# requests-file                 1.5.1
# rich                          12.5.1
# rope                          0.22.0
# rsa                           4.7.2
# Rtree                         0.9.7
# ruamel-yaml-conda             0.15.100
# s3transfer                    0.5.0
# scikit-image                  0.19.2
# scikit-learn                  1.0.2
# scikit-learn-intelex          2021.20220215.132722
# scipy                         1.7.3
# Scrapy                        2.6.1
# seaborn                       0.11.2
# Send2Trash                    1.8.0
# service-identity              18.1.0
# setuptools                    61.2.0
# sip                           4.19.13
# six                           1.16.0
# smart-open                    5.1.0
# sniffio                       1.2.0
# snowballstemmer               2.2.0
# sortedcollections             2.1.0
# sortedcontainers              2.4.0
# soupsieve                     2.3.1
# Sphinx                        4.4.0
# sphinxcontrib-applehelp       1.0.2
# sphinxcontrib-devhelp         1.0.2
# sphinxcontrib-htmlhelp        2.0.0
# sphinxcontrib-jsmath          1.0.1
# sphinxcontrib-qthelp          1.0.3
# sphinxcontrib-serializinghtml 1.1.5
# spotdl                        3.9.6
# spotipy                       2.20.0
# spyder                        5.1.5
# spyder-kernels                2.1.3
# SQLAlchemy                    1.4.32
# stack-data                    0.2.0
# statsmodels                   0.13.2
# sympy                         1.10.1
# tables                        3.6.1
# tabulate                      0.8.9
# TBB                           0.2
# tblib                         1.7.0
# tenacity                      8.0.1
# terminado                     0.13.1
# testpath                      0.5.0
# text-unidecode                1.3
# textdistance                  4.2.1
# threadpoolctl                 2.2.0
# three-merge                   0.1.1
# tifffile                      2021.7.2
# tinycss                       0.4
# tldextract                    3.2.0
# toml                          0.10.2
# tomli                         1.2.2
# toolz                         0.11.2
# tornado                       6.1
# tqdm                          4.64.0
# traitlets                     5.1.1
# Twisted                       22.2.0
# typed-ast                     1.4.3
# typing_extensions             4.1.1
# ujson                         5.1.0
# Unidecode                     1.2.0
# urllib3                       1.26.9
# virtualenv                    20.14.1
# w3lib                         1.21.0
# watchdog                      2.1.6
# wcwidth                       0.2.5
# webencodings                  0.5.1
# websocket-client              0.58.0
# websockets                    10.3
# Werkzeug                      2.0.3
# wheel                         0.37.1
# widgetsnbextension            3.5.2
# wrapt                         1.12.1
# wurlitzer                     3.0.2
# xarray                        0.20.1
# xlrd                          2.0.1
# XlsxWriter                    3.0.3
# xlwings                       0.24.9
# yapf                          0.31.0
# yarl                          1.6.3
# yt-dlp                        2022.6.29
# ytmusicapi                    0.22.0
# zict                          2.0.0
# zipp                          3.7.0
# zope.interface                5.4.0

# %% [markdown]
# Then, we will load the necessary libraries.

# %%
from randomuser import RandomUser
import pandas as pd

# %% [markdown]
# First, we will create a random user object, r.

# %%
r = RandomUser()

# %% [markdown]
# Then, using `generate_users()` function, we get a list of random 10 users.

# %%
some_list = r.generate_users(10)

# %%
some_list
# Out:
# [<randomuser.RandomUser at 0x7f93b9092580>,
#  <randomuser.RandomUser at 0x7f93b93d66a0>,
#  <randomuser.RandomUser at 0x7f93b93d6520>,
#  <randomuser.RandomUser at 0x7f93b93d6a30>,
#  <randomuser.RandomUser at 0x7f93b93d6a00>,
#  <randomuser.RandomUser at 0x7f93b93d6af0>,
#  <randomuser.RandomUser at 0x7f93b93d66d0>,
#  <randomuser.RandomUser at 0x7f93b93d69d0>,
#  <randomuser.RandomUser at 0x7f93b93d6280>,
#  <randomuser.RandomUser at 0x7f93b93d63d0>]

# %% [markdown]
# The **"Get Methods"** functions mentioned at the beginning of this notebook, can generate the required parameters to construct a dataset. For example, to get full name, we call `get_full_name()` function.

# %%
name = r.get_full_name()

# %% [markdown]
# Let's say we only need 10 users with full names and their email addresses. We can write a "for-loop" to print these 10 users.

# %%
for user in some_list:
    print (user.get_full_name()," ",user.get_email())
# Out:
# Osório Jesus   osorio.jesus@example.com
# Elliot Ingvaldsen   elliot.ingvaldsen@example.com
# Wubbo Kluijtmans   wubbo.kluijtmans@example.com
# Marceau Giraud   marceau.giraud@example.com
# Knut Buchner   knut.buchner@example.com
# Louise Sullivan   louise.sullivan@example.com
# Kylie Snyder   kylie.snyder@example.com
# Paul Lee   paul.lee@example.com
# Didrik Hatland   didrik.hatland@example.com
# مرسانا زارعی   mrsn.zraay@example.com

# %% [markdown]
# ## Exercise 1
#
# In this Exercise, generate photos of the random 5 users.

# %%
## Write your code here
for user in some_list:
    print(user.get_picture())
# Out:
# https://randomuser.me/api/portraits/men/36.jpg
# https://randomuser.me/api/portraits/men/5.jpg
# https://randomuser.me/api/portraits/men/6.jpg
# https://randomuser.me/api/portraits/men/9.jpg
# https://randomuser.me/api/portraits/men/32.jpg
# https://randomuser.me/api/portraits/women/16.jpg
# https://randomuser.me/api/portraits/women/46.jpg
# https://randomuser.me/api/portraits/men/61.jpg
# https://randomuser.me/api/portraits/men/7.jpg
# https://randomuser.me/api/portraits/women/82.jpg

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# for user in some_list:
#     print (user.get_picture())
# ```
#
# </details>

# %% [markdown]
# To generate a table with information about the users, we can write a function containing all desirable parameters. For example, name, gender, city, etc. The parameters will depend on the requirements of the test to be performed. We call the Get Methods, listed at the beginning of this notebook. Then, we return pandas dataframe with the users.

# %%
def get_users():
    users =[]
     
    for user in RandomUser.generate_users(10):
        users.append({"Name":user.get_full_name(),"Gender":user.get_gender(),"City":user.get_city(),"State":user.get_state(),"Email":user.get_email(), "DOB":user.get_dob(),"Picture":user.get_picture()})
      
    return pd.DataFrame(users)

# %%
get_users()
# Out:
#               Name  Gender       City            State  \
# 0      Ian Nicolas    male    Muzzano         Obwalden
# 1       Keira Chen  female  Greymouth         Gisborne
# 2     Eline Martin  female      Stans           Aargau
# 3  Jayden Anderson    male    Preston  Buckinghamshire
# 4    Samantha Chen  female   Hastings        Northland
# 5     Amparo Bravo  female      Parla           Aragón
# 6   Meint Stegenga    male   Armhoede          Utrecht
# 7    Angie Andrews  female   Coventry       Merseyside
# 8   Luukas Haataja    male      Turku      Kymenlaakso
# 9   Maurice Turner    male    Belfast            Powys
#
#                          Email                       DOB  \
# 0      ian.nicolas@example.com  1959-04-16T06:52:48.179Z
# 1       keira.chen@example.com  1980-03-21T07:26:32.146Z
# 2     eline.martin@example.com  1967-02-21T00:52:51.624Z
# 3  jayden.anderson@example.com  1984-10-07T16:52:12.698Z
# 4    samantha.chen@example.com  1966-08-23T13:10:27.456Z
# 5     amparo.bravo@example.com  1985-12-22T22:08:13.847Z
# 6   meint.stegenga@example.com  1967-12-06T12:21:56.417Z
# 7    angie.andrews@example.com  1975-06-14T11:40:14.279Z
# 8   luukas.haataja@example.com  1998-04-30T22:42:08.486Z
# 9   maurice.turner@example.com  1957-09-28T21:32:51.600Z
#
#                                             Picture
# 0    https://randomuser.me/api/portraits/men/87.jpg
# 1  https://randomuser.me/api/portraits/women/11.jpg
# 2  https://randomuser.me/api/portraits/women/66.jpg
# 3    https://randomuser.me/api/portraits/men/87.jpg
# 4  https://randomuser.me/api/portraits/women/26.jpg
# 5  https://randomuser.me/api/portraits/women/25.jpg
# 6    https://randomuser.me/api/portraits/men/94.jpg
# 7  https://randomuser.me/api/portraits/women/27.jpg
# 8    https://randomuser.me/api/portraits/men/27.jpg
# 9     https://randomuser.me/api/portraits/men/5.jpg

# %%
df1 = pd.DataFrame(get_users())  
df1
# Out:
#                 Name  Gender         City              State  \
# 0        احسان نجاتی    male     خرم‌آباد  سیستان و بلوچستان
# 1         Julia Sanz  female       Cuenca          Cantabria
# 2       Clara Mackay  female   Burlington            Ontario
# 3        Joshua Hall    male       Timaru            Waikato
# 4      Amâncio Gomes    male  Parauapebas          Tocantins
# 5       Jacira Costa  female        Bauru       Minas Gerais
# 6  Frederik Andersen    male    Snertinge            Danmark
# 7     Kadir Küçükler    male     Erzincan            Erzurum
# 8     Yasser Lauwers    male   Feanwalden       Zuid-Holland
# 9   Karl-August Mair    male    Bredstedt          Thüringen
#
#                            Email                       DOB  \
# 0           hsn.njty@example.com  1992-03-04T23:58:12.871Z
# 1         julia.sanz@example.com  1981-02-27T05:19:05.689Z
# 2       clara.mackay@example.com  1949-05-14T10:14:29.916Z
# 3        joshua.hall@example.com  1959-10-21T10:12:42.013Z
# 4      amancio.gomes@example.com  1988-12-02T12:04:50.550Z
# 5       jacira.costa@example.com  1985-03-16T07:58:39.778Z
# 6  frederik.andersen@example.com  1973-09-25T00:46:02.849Z
# 7     kadir.kucukler@example.com  1970-09-05T07:18:31.780Z
# 8     yasser.lauwers@example.com  1990-09-30T19:43:46.819Z
# 9   karl-august.mair@example.com  1951-01-20T03:04:54.030Z
#
#                                             Picture
# 0     https://randomuser.me/api/portraits/men/5.jpg
# 1  https://randomuser.me/api/portraits/women/70.jpg
# 2  https://randomuser.me/api/portraits/women/45.jpg
# 3    https://randomuser.me/api/portraits/men/93.jpg
# 4    https://randomuser.me/api/portraits/men/19.jpg
# 5   https://randomuser.me/api/portraits/women/6.jpg
# 6     https://randomuser.me/api/portraits/men/8.jpg
# 7    https://randomuser.me/api/portraits/men/43.jpg
# 8    https://randomuser.me/api/portraits/men/21.jpg
# 9    https://randomuser.me/api/portraits/men/47.jpg

# %% [markdown]
# Now we have a *pandas* dataframe that can be used for any testing purposes that the tester might have.

# %% [markdown]
# ## Example 2: Fruitvice API
#
# Another, more common way to use APIs, is through `requests` library. The next lab, Requests and HTTP, will contain more information about requests.
#
# We will start by importing all required libraries.

# %%
import requests
import json

# %% [markdown]
# We will obtain the [fruitvice](https://www.fruityvice.com/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0101ENSkillsNetwork19487395-2022-01-01) API data using `requests.get("url")` function. The data is in a json format.

# %%
data = requests.get("https://www.fruityvice.com/api/fruit/all")

# %% [markdown]
# We will retrieve results using `json.loads()` function.

# %%
results = json.loads(data.text)

# %% [markdown]
# We will convert our json data into *pandas* data frame.

# %%
pd.DataFrame(results)
# Out:
#          genus          name  id           family             order  \
# 0        Malus         Apple   6         Rosaceae           Rosales
# 1       Prunus       Apricot  35         Rosaceae           Rosales
# 2         Musa        Banana   1         Musaceae      Zingiberales
# 3        Rubus    Blackberry  64         Rosaceae           Rosales
# 4     Fragaria     Blueberry  33         Rosaceae           Rosales
# 5       Prunus        Cherry   9         Rosaceae              None
# 6        Durio        Durian  60        Malvaceae          Malvales
# 7        Ficus           Fig  68         Moraceae           Rosales
# 8        Ribes    Gooseberry  69  Grossulariaceae      Saxifragales
# 9        Vitis        Grapes  47         Vitaceae           Vitales
# 10       Malus    GreenApple  72         Rosaceae           Rosales
# 11     Psidium         Guava  37        Myrtaceae          Myrtales
# 12     Apteryx          Kiwi  66    Actinidiaceae  Struthioniformes
# 13      Citrus         Lemon  26         Rutaceae        Sapindales
# 14      Citrus          Lime  44         Rutaceae        Sapindales
# 15   Vaccinium   Lingonberry  65        Ericaceae          Ericales
# 16      Litchi        Lychee  67      Sapindaceae        Sapindales
# 17   Mangifera         Mango  27    Anacardiaceae        Sapindales
# 18     Cucumis         Melon  41    Cucurbitaceae     Cucurbitaceae
# 19      Citrus        Orange   2         Rutaceae        Sapindales
# 20      Carica        Papaya  42       Caricaceae         Caricacea
# 21  Passiflora  Passionfruit  70   Passifloraceae      Malpighiales
# 22       Pyrus          Pear   4         Rosaceae           Rosales
# 23   Diospyros     Persimmon  52        Ebenaceae           Rosales
# 24      Ananas     Pineapple  10     Bromeliaceae            Poales
# 25      Prunus          Plum  71         Rosaceae           Rosales
# 26       Rubus     Raspberry  23         Rosaceae           Rosales
# 27    Fragaria    Strawberry   3         Rosaceae           Rosales
# 28     Solanum        Tomato   5       Solanaceae         Solanales
# 29    Spondias          Umbu  73    Anacardiaceae                 0
# 30   Citrullus    Watermelon  25    Cucurbitaceae      Cucurbitales
#
#                                            nutritions
# 0   {'carbohydrates': 11.4, 'protein': 0.3, 'fat':...
# 1   {'carbohydrates': 3.9, 'protein': 0.5, 'fat': ...
# 2   {'carbohydrates': 22, 'protein': 1, 'fat': 0.2...
# 3   {'carbohydrates': 9, 'protein': 1.3, 'fat': 0....
# 4   {'carbohydrates': 5.5, 'protein': 0, 'fat': 0....
# 5   {'carbohydrates': 12, 'protein': 1, 'fat': 0.3...
# 6   {'carbohydrates': 27.1, 'protein': 1.5, 'fat':...
# 7   {'carbohydrates': 19, 'protein': 0.8, 'fat': 0...
# 8   {'carbohydrates': 10, 'protein': 0.9, 'fat': 0...
# 9   {'carbohydrates': 18.1, 'protein': 0.72, 'fat'...
# 10  {'carbohydrates': 3.1, 'protein': 0.4, 'fat': ...
# 11  {'carbohydrates': 14, 'protein': 2.6, 'fat': 1...
# 12  {'carbohydrates': 15, 'protein': 1.1, 'fat': 0...
# 13  {'carbohydrates': 9, 'protein': 1.1, 'fat': 0....
# 14  {'carbohydrates': 8.4, 'protein': 0.3, 'fat': ...
# 15  {'carbohydrates': 11.3, 'protein': 0.75, 'fat'...
# 16  {'carbohydrates': 17, 'protein': 0.8, 'fat': 0...
# 17  {'carbohydrates': 15, 'protein': 0.82, 'fat': ...
# 18  {'carbohydrates': 8, 'protein': 0, 'fat': 0, '...
# 19  {'carbohydrates': 8.3, 'protein': 1, 'fat': 0....
# 20  {'carbohydrates': 11, 'protein': 0, 'fat': 0.4...
# 21  {'carbohydrates': 22.4, 'protein': 2.2, 'fat':...
# 22  {'carbohydrates': 15, 'protein': 0.4, 'fat': 0...
# 23  {'carbohydrates': 18, 'protein': 0, 'fat': 0, ...
# 24  {'carbohydrates': 13.12, 'protein': 0.54, 'fat...
# 25  {'carbohydrates': 11.4, 'protein': 0.7, 'fat':...
# 26  {'carbohydrates': 12, 'protein': 1.2, 'fat': 0...
# 27  {'carbohydrates': 5.5, 'protein': 0.8, 'fat': ...
# 28  {'carbohydrates': 3.9, 'protein': 0.9, 'fat': ...
# 29  {'carbohydrates': 0, 'protein': 0, 'fat': 0, '...
# 30  {'carbohydrates': 8, 'protein': 0.6, 'fat': 0....

# %% [markdown]
# The result is in a nested json format. The 'nutrition' column contains multiple subcolumns, so the data needs to be 'flattened' or normalized.

# %%
df2 = pd.json_normalize(results)

# %%
df2
# Out:
#          genus          name  id           family             order  \
# 0        Malus         Apple   6         Rosaceae           Rosales
# 1       Prunus       Apricot  35         Rosaceae           Rosales
# 2         Musa        Banana   1         Musaceae      Zingiberales
# 3        Rubus    Blackberry  64         Rosaceae           Rosales
# 4     Fragaria     Blueberry  33         Rosaceae           Rosales
# 5       Prunus        Cherry   9         Rosaceae              None
# 6        Durio        Durian  60        Malvaceae          Malvales
# 7        Ficus           Fig  68         Moraceae           Rosales
# 8        Ribes    Gooseberry  69  Grossulariaceae      Saxifragales
# 9        Vitis        Grapes  47         Vitaceae           Vitales
# 10       Malus    GreenApple  72         Rosaceae           Rosales
# 11     Psidium         Guava  37        Myrtaceae          Myrtales
# 12     Apteryx          Kiwi  66    Actinidiaceae  Struthioniformes
# 13      Citrus         Lemon  26         Rutaceae        Sapindales
# 14      Citrus          Lime  44         Rutaceae        Sapindales
# 15   Vaccinium   Lingonberry  65        Ericaceae          Ericales
# 16      Litchi        Lychee  67      Sapindaceae        Sapindales
# 17   Mangifera         Mango  27    Anacardiaceae        Sapindales
# 18     Cucumis         Melon  41    Cucurbitaceae     Cucurbitaceae
# 19      Citrus        Orange   2         Rutaceae        Sapindales
# 20      Carica        Papaya  42       Caricaceae         Caricacea
# 21  Passiflora  Passionfruit  70   Passifloraceae      Malpighiales
# 22       Pyrus          Pear   4         Rosaceae           Rosales
# 23   Diospyros     Persimmon  52        Ebenaceae           Rosales
# 24      Ananas     Pineapple  10     Bromeliaceae            Poales
# 25      Prunus          Plum  71         Rosaceae           Rosales
# 26       Rubus     Raspberry  23         Rosaceae           Rosales
# 27    Fragaria    Strawberry   3         Rosaceae           Rosales
# 28     Solanum        Tomato   5       Solanaceae         Solanales
# 29    Spondias          Umbu  73    Anacardiaceae                 0
# 30   Citrullus    Watermelon  25    Cucurbitaceae      Cucurbitales
#
#     nutritions.carbohydrates  nutritions.protein  nutritions.fat  \
# 0                      11.40                0.30            0.40
# 1                       3.90                0.50            0.10
# 2                      22.00                1.00            0.20
# 3                       9.00                1.30            0.40
# 4                       5.50                0.00            0.40
# 5                      12.00                1.00            0.30
# 6                      27.10                1.50            5.30
# 7                      19.00                0.80            0.30
# 8                      10.00                0.90            0.60
# 9                      18.10                0.72            0.16
# 10                      3.10                0.40            0.10
# 11                     14.00                2.60            1.00
# 12                     15.00                1.10            0.50
# 13                      9.00                1.10            0.30
# 14                      8.40                0.30            0.10
# 15                     11.30                0.75            0.34
# 16                     17.00                0.80            0.44
# 17                     15.00                0.82            0.38
# 18                      8.00                0.00            0.00
# 19                      8.30                1.00            0.20
# 20                     11.00                0.00            0.40
# 21                     22.40                2.20            0.70
# 22                     15.00                0.40            0.10
# 23                     18.00                0.00            0.00
# 24                     13.12                0.54            0.12
# 25                     11.40                0.70            0.28
# 26                     12.00                1.20            0.70
# 27                      5.50                0.80            0.40
# 28                      3.90                0.90            0.20
# 29                      0.00                0.00            0.00
# 30                      8.00                0.60            0.20
#
#     nutritions.calories  nutritions.sugar
# 0                    52             10.30
# 1                    15              3.20
# 2                    96             17.20
# 3                    40              4.50
# 4                    29              5.40
# 5                    50              8.00
# 6                   147              6.75
# 7                    74             16.00
# 8                    44              0.00
# 9                    69             15.48
# 10                   21              6.40
# 11                   68              9.00
# 12                   61              9.00
# 13                   29              2.50
# 14                   25              1.70
# 15                   50              5.74
# 16                   66             15.00
# 17                   60             13.70
# 18                   34              8.00
# 19                   43              8.20
# 20                   43              1.00
# 21                   97             11.20
# 22                   57             10.00
# 23                   81             18.00
# 24                   50              9.85
# 25                   46              9.92
# 26                   53              4.40
# 27                   29              5.40
# 28                   74              2.60
# 29                    0              0.00
# 30                   30              6.00

# %% [markdown]
# Let's see if we can extract some information from this dataframe. Perhaps, we need to know the family and genus of a cherry.

# %%
cherry = df2.loc[df2["name"] == 'Cherry']
(cherry.iloc[0]['family']) , (cherry.iloc[0]['genus'])
# Out:
# ('Rosaceae', 'Prunus')

# %% [markdown]
# ## Exercise 2
#
# In this Exercise, find out how many calories are contained in a banana.

# %%
# Write your code here
banana = df2.loc[df2["name"] == "Banana"]
banana.iloc[0]["nutritions.calories"]
# Out:
# 96

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# cal_banana = df2.loc[df2["name"] == 'Banana']
# cal_banana.iloc[0]['nutritions.calories']
# ```
#
# </details>

# %% [markdown]
# ## Exercise 3
#
# This [page](https://github.com/public-apis/public-apis#animals) contains a list of free public APIs. Choose any API of your interest and use it to load/extract some information, as shown in the example above.
#
# 1.  Using `requests.get("url")` function, load your data.

# %%
# Write your code here
country = {"country" : "Germany"}
r = requests.get("https://covid-api.mmediagroup.fr/v1/cases", params=country)

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# data2 = requests.get("https://www.fishwatch.gov/api/species")
# ```
#
# </details>

# %% [markdown]
# 2.  Retrieve results using `json.loads()` function.

# %%
# Write your code here
results = json.loads(r.text)
results
# Out:
# {'All': {'confirmed': 32680356,
#   'recovered': 0,
#   'deaths': 148933,
#   'country': 'Germany',
#   'population': 82114224,
#   'sq_km_area': 357022,
#   'life_expectancy': '77.4',
#   'elevation_in_meters': 263,
#   'continent': 'Europe',
#   'abbreviation': 'DE',
#   'location': 'Western Europe',
#   'iso': 276,
#   'capital_city': 'Berlin'},
#  'Baden-Wurttemberg': {'lat': '48.6616',
#   'long': '9.3501',
#   'confirmed': 4438037,
#   'recovered': 0,
#   'deaths': 17199,
#   'updated': '2022-09-18 04:22:50'},
#  'Bayern': {'lat': '48.7904',
#   'long': '11.4979',
#   'confirmed': 5923559,
#   'recovered': 0,
#   'deaths': 25666,
#   'updated': '2022-09-18 04:22:50'},
#  'Berlin': {'lat': '52.52',
#   'long': '13.405',
#   'confirmed': 1248916,
#   'recovered': 0,
#   'deaths': 4795,
#   'updated': '2022-09-18 04:22:50'},
#  'Brandenburg': {'lat': '52.4125',
#   'long': '12.5316',
#   'confirmed': 938840,
#   'recovered': 0,
#   'deaths': 5889,
#   'updated': '2022-09-18 04:22:50'},
#  'Bremen': {'lat': '53.0793',
#   'long': '8.8017',
#   'confirmed': 255097,
#   'recovered': 0,
#   'deaths': 831,
#   'updated': '2022-09-18 04:22:50'},
#  'Hamburg': {'lat': '53.5511',
#   'long': '9.9937',
#   'confirmed': 720657,
#   'recovered': 0,
#   'deaths': 3018,
#   'updated': '2022-09-18 04:22:50'},
#  'Hessen': {'lat': '50.6521',
#   'long': '9.1624',
#   'confirmed': 2455316,
#   'recovered': 0,
#   'deaths': 11028,
#   'updated': '2022-09-18 04:22:50'},
#  'Mecklenburg-Vorpommern': {'lat': '53.6127',
#   'long': '12.4296',
#   'confirmed': 595293,
#   'recovered': 0,
#   'deaths': 2441,
#   'updated': '2022-09-18 04:22:50'},
#  'Niedersachsen': {'lat': '52.6367',
#   'long': '9.8451',
#   'confirmed': 3158513,
#   'recovered': 0,
#   'deaths': 10697,
#   'updated': '2022-09-18 04:22:50'},
#  'Nordrhein-Westfalen': {'lat': '51.4332',
#   'long': '7.6616',
#   'confirmed': 6705731,
#   'recovered': 0,
#   'deaths': 27266,
#   'updated': '2022-09-18 04:22:50'},
#  'Rheinland-Pfalz': {'lat': '50.1183',
#   'long': '7.309',
#   'confirmed': 1475219,
#   'recovered': 0,
#   'deaths': 6130,
#   'updated': '2022-09-18 04:22:50'},
#  'Saarland': {'lat': '49.3964',
#   'long': '7.023',
#   'confirmed': 404436,
#   'recovered': 0,
#   'deaths': 1841,
#   'updated': '2022-09-18 04:22:50'},
#  'Sachsen': {'lat': '51.1045',
#   'long': '13.2017',
#   'confirmed': 1737276,
#   'recovered': 0,
#   'deaths': 15978,
#   'updated': '2022-09-18 04:22:50'},
#  'Sachsen-Anhalt': {'lat': '51.9503',
#   'long': '11.6923',
#   'confirmed': 832084,
#   'recovered': 0,
#   'deaths': 5692,
#   'updated': '2022-09-18 04:22:50'},
#  'Schleswig-Holstein': {'lat': '54.2194',
#   'long': '9.6961',
#   'confirmed': 998631,
#   'recovered': 0,
#   'deaths': 2858,
#   'updated': '2022-09-18 04:22:50'},
#  'Thuringen': {'lat': '51.011',
#   'long': '10.8453',
#   'confirmed': 792751,
#   'recovered': 0,
#   'deaths': 7604,
#   'updated': '2022-09-18 04:22:50'},
#  'Unknown': {'lat': '',
#   'long': '',
#   'confirmed': 0,
#   'recovered': 0,
#   'deaths': 0,
#   'updated': '2022-09-18 04:22:50'}}

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# results2 = json.loads(data2.text)
# ```
#
# </details>

# %% [markdown]
# 3.  Convert json data into *pandas* data frame.

# %%
# Write your code here
df = pd.DataFrame(results)
df
# Out:
#                                 All    Baden-Wurttemberg               Bayern  \
# confirmed                  32680356              4438037              5923559
# recovered                         0                    0                    0
# deaths                       148933                17199                25666
# country                     Germany                  NaN                  NaN
# population                 82114224                  NaN                  NaN
# sq_km_area                   357022                  NaN                  NaN
# life_expectancy                77.4                  NaN                  NaN
# elevation_in_meters             263                  NaN                  NaN
# continent                    Europe                  NaN                  NaN
# abbreviation                     DE                  NaN                  NaN
# location             Western Europe                  NaN                  NaN
# iso                             276                  NaN                  NaN
# capital_city                 Berlin                  NaN                  NaN
# lat                             NaN              48.6616              48.7904
# long                            NaN               9.3501              11.4979
# updated                         NaN  2022-09-18 04:22:50  2022-09-18 04:22:50
#
#                                   Berlin          Brandenburg  \
# confirmed                        1248916               938840
# recovered                              0                    0
# deaths                              4795                 5889
# country                              NaN                  NaN
# population                           NaN                  NaN
# sq_km_area                           NaN                  NaN
# life_expectancy                      NaN                  NaN
# elevation_in_meters                  NaN                  NaN
# continent                            NaN                  NaN
# abbreviation                         NaN                  NaN
# location                             NaN                  NaN
# iso                                  NaN                  NaN
# capital_city                         NaN                  NaN
# lat                                52.52              52.4125
# long                              13.405              12.5316
# updated              2022-09-18 04:22:50  2022-09-18 04:22:50
#
#                                   Bremen              Hamburg  \
# confirmed                         255097               720657
# recovered                              0                    0
# deaths                               831                 3018
# country                              NaN                  NaN
# population                           NaN                  NaN
# sq_km_area                           NaN                  NaN
# life_expectancy                      NaN                  NaN
# elevation_in_meters                  NaN                  NaN
# continent                            NaN                  NaN
# abbreviation                         NaN                  NaN
# location                             NaN                  NaN
# iso                                  NaN                  NaN
# capital_city                         NaN                  NaN
# lat                              53.0793              53.5511
# long                              8.8017               9.9937
# updated              2022-09-18 04:22:50  2022-09-18 04:22:50
#
#                                   Hessen Mecklenburg-Vorpommern  \
# confirmed                        2455316                 595293
# recovered                              0                      0
# deaths                             11028                   2441
# country                              NaN                    NaN
# population                           NaN                    NaN
# sq_km_area                           NaN                    NaN
# life_expectancy                      NaN                    NaN
# elevation_in_meters                  NaN                    NaN
# continent                            NaN                    NaN
# abbreviation                         NaN                    NaN
# location                             NaN                    NaN
# iso                                  NaN                    NaN
# capital_city                         NaN                    NaN
# lat                              50.6521                53.6127
# long                              9.1624                12.4296
# updated              2022-09-18 04:22:50    2022-09-18 04:22:50
#
#                            Niedersachsen  Nordrhein-Westfalen  \
# confirmed                        3158513              6705731
# recovered                              0                    0
# deaths                             10697                27266
# country                              NaN                  NaN
# population                           NaN                  NaN
# sq_km_area                           NaN                  NaN
# life_expectancy                      NaN                  NaN
# elevation_in_meters                  NaN                  NaN
# continent                            NaN                  NaN
# abbreviation                         NaN                  NaN
# location                             NaN                  NaN
# iso                                  NaN                  NaN
# capital_city                         NaN                  NaN
# lat                              52.6367              51.4332
# long                              9.8451               7.6616
# updated              2022-09-18 04:22:50  2022-09-18 04:22:50
#
#                          Rheinland-Pfalz             Saarland  \
# confirmed                        1475219               404436
# recovered                              0                    0
# deaths                              6130                 1841
# country                              NaN                  NaN
# population                           NaN                  NaN
# sq_km_area                           NaN                  NaN
# life_expectancy                      NaN                  NaN
# elevation_in_meters                  NaN                  NaN
# continent                            NaN                  NaN
# abbreviation                         NaN                  NaN
# location                             NaN                  NaN
# iso                                  NaN                  NaN
# capital_city                         NaN                  NaN
# lat                              50.1183              49.3964
# long                               7.309                7.023
# updated              2022-09-18 04:22:50  2022-09-18 04:22:50
#
#                                  Sachsen       Sachsen-Anhalt  \
# confirmed                        1737276               832084
# recovered                              0                    0
# deaths                             15978                 5692
# country                              NaN                  NaN
# population                           NaN                  NaN
# sq_km_area                           NaN                  NaN
# life_expectancy                      NaN                  NaN
# elevation_in_meters                  NaN                  NaN
# continent                            NaN                  NaN
# abbreviation                         NaN                  NaN
# location                             NaN                  NaN
# iso                                  NaN                  NaN
# capital_city                         NaN                  NaN
# lat                              51.1045              51.9503
# long                             13.2017              11.6923
# updated              2022-09-18 04:22:50  2022-09-18 04:22:50
#
#                       Schleswig-Holstein            Thuringen  \
# confirmed                         998631               792751
# recovered                              0                    0
# deaths                              2858                 7604
# country                              NaN                  NaN
# population                           NaN                  NaN
# sq_km_area                           NaN                  NaN
# life_expectancy                      NaN                  NaN
# elevation_in_meters                  NaN                  NaN
# continent                            NaN                  NaN
# abbreviation                         NaN                  NaN
# location                             NaN                  NaN
# iso                                  NaN                  NaN
# capital_city                         NaN                  NaN
# lat                              54.2194               51.011
# long                              9.6961              10.8453
# updated              2022-09-18 04:22:50  2022-09-18 04:22:50
#
#                                  Unknown
# confirmed                              0
# recovered                              0
# deaths                                 0
# country                              NaN
# population                           NaN
# sq_km_area                           NaN
# life_expectancy                      NaN
# elevation_in_meters                  NaN
# continent                            NaN
# abbreviation                         NaN
# location                             NaN
# iso                                  NaN
# capital_city                         NaN
# lat
# long
# updated              2022-09-18 04:22:50

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# df3 = pd.DataFrame(results2)
# df3
# ```
#
# </details>

# %% [markdown]
# # Congratulations! - You have completed the lab

# %% [markdown]
# ## Author
#
# [Svitlana Kramar](https://www.linkedin.com/in/svitlana-kramar?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0101ENSkillsNetwork19487395-2022-01-01)
#
# Svitlana is a master’s degree Data Science and Analytics student at University of Calgary, who enjoys travelling, learning new languages and cultures and loves spreading her passion for Data Science.

# %% [markdown]
# Copyright © 2020 IBM Corporation. All rights reserved.
